# %% [markdown]
# <a href="https://colab.research.google.com/github/hohno-46466/tZone--GoogleColab--Test00/blob/master/Untitled0_20210520.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 2 + 4 + 6 + 8 + 10
x
# Out:
# 30

# %%
s = 20*60*60*365 + 123
s
# Out:
# 26280123

# %%
import numpy as np
from matplotlib import pyplot as plt
ys = 200 + np.random.randn(100)
x = [ x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 199, where=(ys > 197), facecolor='g', alpha=0.6)
plt.title("Hello, World! (updated)")
plt.show()
